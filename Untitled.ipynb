# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('295273672130-cur-with-tags-2021-02.csv')

df.head()
# Out:
#    InvoiceID  PayerAccountId  LinkedAccountId  RecordId  \
# 0  685231805    9.618590e+11     2.952740e+11  LineItem
# 1  685231805    9.618590e+11     2.952740e+11  LineItem
# 2  685231805    9.618590e+11     2.952740e+11  LineItem
# 3  685231805    9.618590e+11     2.952740e+11  LineItem
# 4  685231805    9.618590e+11     2.952740e+11  LineItem
#
#                                     ProductName                     UsageType  \
# 0  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 1  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 2  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 3  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 4  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
#
#   Operation AvailabilityZone ReservedInstance  \
# 0    Hourly              NaN                N
# 1    Hourly  ap-northeast-1a                N
# 2    Hourly  ap-northeast-1a                N
# 3    Hourly  ap-northeast-1a                N
# 4    Hourly  ap-northeast-1a                N
#
#                                      ItemDescription        UsageStartDate  \
# 0  Tax for product code b4oaowtu943z36a9jxepql6gh...  2021-02-01T00:00:00Z
# 1  AWS Marketplace hourly software usage|ap-north...  2021-02-01T00:00:00Z
# 2  AWS Marketplace hourly software usage|ap-north...  2021-02-01T01:00:00Z
# 3  AWS Marketplace hourly software usage|ap-north...  2021-02-01T02:00:00Z
# 4  AWS Marketplace hourly software usage|ap-north...  2021-02-01T03:00:00Z
#
#            UsageEndDate  UsageQuantity  UnblendedRate  UnBlendedCost  \
# 0  2021-03-01T00:00:00Z            1.0            NaN           8.73
# 1  2021-02-01T01:00:00Z            1.0            0.3           0.30
# 2  2021-02-01T02:00:00Z            1.0            0.3           0.30
# 3  2021-02-01T03:00:00Z            1.0            0.3           0.30
# 4  2021-02-01T04:00:00Z            1.0            0.3           0.30
#
#                                           ResourceId  \
# 0                                                NaN
# 1  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 2  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 3  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 4  arn:aws:ec2:ap-northeast-1:295273672130:instan...
#
#                              aws_createdBy  user_Division  user_ENV
# 0                                      NaN            NaN       NaN
# 1  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao            NaN       NaN
# 2  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao            NaN       NaN
# 3  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao            NaN       NaN
# 4  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao            NaN       NaN

# %%
for col in df:
    print(col + ': '+ str(len(df[col].unique())))
# Out:
# InvoiceID: 2
# PayerAccountId: 1
# LinkedAccountId: 1
# RecordId: 1
# ProductName: 27
# UsageType: 311
# Operation: 149
# AvailabilityZone: 10
# ReservedInstance: 1
# ItemDescription: 403
# UsageStartDate: 672
# UsageEndDate: 675
# UsageQuantity: 28967
# UnblendedRate: 74
# UnBlendedCost: 15151
# ResourceId: 1226
# aws_createdBy: 17
# user_Division: 1
# user_ENV: 1

# %%
# drop the unique value
df = df.drop(columns=['InvoiceID', 'PayerAccountId', 'LinkedAccountId', 'RecordId', 'ReservedInstance', 'user_Division', 'user_ENV'])
# drop ItemDescription for already exist feature
df = df.drop(columns=['ItemDescription'])

df.head()
# Out:
#                                     ProductName                     UsageType  \
# 0  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 1  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 2  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 3  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
# 4  OpenVPN Access Server (50 Connected Devices)  APN1-SoftwareUsage:t3.medium
#
#   Operation AvailabilityZone        UsageStartDate          UsageEndDate  \
# 0    Hourly              NaN  2021-02-01T00:00:00Z  2021-03-01T00:00:00Z
# 1    Hourly  ap-northeast-1a  2021-02-01T00:00:00Z  2021-02-01T01:00:00Z
# 2    Hourly  ap-northeast-1a  2021-02-01T01:00:00Z  2021-02-01T02:00:00Z
# 3    Hourly  ap-northeast-1a  2021-02-01T02:00:00Z  2021-02-01T03:00:00Z
# 4    Hourly  ap-northeast-1a  2021-02-01T03:00:00Z  2021-02-01T04:00:00Z
#
#    UsageQuantity  UnblendedRate  UnBlendedCost  \
# 0            1.0            NaN           8.73
# 1            1.0            0.3           0.30
# 2            1.0            0.3           0.30
# 3            1.0            0.3           0.30
# 4            1.0            0.3           0.30
#
#                                           ResourceId  \
# 0                                                NaN
# 1  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 2  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 3  arn:aws:ec2:ap-northeast-1:295273672130:instan...
# 4  arn:aws:ec2:ap-northeast-1:295273672130:instan...
#
#                              aws_createdBy
# 0                                      NaN
# 1  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao
# 2  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao
# 3  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao
# 4  IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao

# %%
df['Operation'].unique()
# Out:
# array(['Hourly', 'RunInstances', 'RunInstances:0010', 'T3CPUCredits', nan,
#        'PutLogEvents', 'LoadBalancing:Network',
#        'LoadBalancing:Application', 'CreateDBInstance:0014',
#        'RunInstances:0010:SV008', 'FargateTask', 'PublicIP-Out',
#        'CreateOperation', 'HostingStorage', 'InterZone-In',
#        'InterZone-Out', 'CreateVolume-Gp2', 'AssociateAddressVPC',
#        'LoadBalancing', 'NatGateway', 'StandardStorage',
#        'ReducedRedundancyStorage', 'CommittedThroughput',
#        'AWSGlobalAccelerator', 'PutObject', 'None', 'Dominant',
#        'Non-dominant', 'USE1-TimedStorage-ByteHrs',
#        'HourlyStorageMetering', 'OneZoneIASizeOverhead', 'Unknown',
#        'RunInstances:0002', 'MetricStorage:AWS/EC2', 'PublicIP-In',
#        'shardHourStorage', 'APN1-TimedStorage-ByteHrs', 'Storage',
#        'LoadBalancing-PublicIP-Out', 'ReadACL', 'UNSUPPORTED',
#        'SecretUsage', 'LoadBalancing-PublicIP-In', 'AAAA',
#        'USE2-TimedStorage-ByteHrs', 'Invoke', 'RunInstances:SV012', 'A',
#        'GetObject', 'Decrypt', 'GetTopicAttributes', 'ListBucketVersions',
#        'Publish', 'Subscribe', 'HeadBucket', 'ReadBucketPolicyStatus',
#        'ReadBucketPublicAccessBlock', 'ReadVersioningProps',
#        'Notification', 'ReadLocation', 'DeleteTopic', 'Unsubscribe',
#        'DashboardHour', 'ReadAccountPublicAccessBlock', 'HeadObject',
#        'MetricStorage', 'SOA', 'RunInstances:SV008', 'DNSKEY',
#        'PutMetricData', 'MX', 'TXT', 'CreateSnapshot',
#        'RunInstances:0010:SV012', 'ListAllMyBuckets', 'ListBucket',
#        'ReadObjectTagging', 'ReadBucketObjectLockConfig',
#        'ReadBucketPolicy', 'ListAliases', 'CAA', 'GetMetricData',
#        'OneZoneIAStorage', 'CNAME', 'UploadPart',
#        'InitiateMultipartUpload', 'ListSecrets', 'CreateSecret',
#        'DescribeSecret', 'GetResourcePolicy', 'DescribeKey', 'List',
#        'CreateBucket', 'GetKeyPolicy', 'GetKeyRotationStatus',
#        'ListResourceTags', 'NS', 'ListTagsForResource', 'PTR', 'SRV',
#        'ListSubscriptions', 'DeleteSecret',
#        'ReadBucketServerSideEncryption', 'WriteBucketPolicy',
#        'ReadBucketWebsite', 'ListTopics', 'ListKeys', 'ANY',
#        'GetSecretValue', 'ExecutionStarted', 'StateRetry',
#        'WriteBucketServerSideEncryption', 'ReadBucketCors',
#        'ReadBucketInventory', 'ReadBucketOwnershipControls',
#        'ReadLogProps', 'ReadRequestPaymentProps', 'GetRandomPassword',
#        'CreateDBInstance', 'PutSecretValue', 'Not Applicable',
#        'HostedZone', 'GenerateDataKey', 'CreateGrant',
#        'ScheduleKeyDeletion', 'ListRepositories', 'ExecutionCompleted',
#        'DeleteAlias', 'WriteBucketPublicAccessBlock', 'ReadAccelerate',
#        'ReadBucketIntelligentTiering', 'ReadBucketLifecycle',
#        'ReadNotificationProps', 'GET', 'CreateTopic',
#        'CompleteMultipartUpload', 'ReadCostAllocation', 'CreateKey',
#        'downloadLayer', 'GetMetricStatistics', 'BackupStorage',
#        'GenerateDataKeyWithoutPlaintext', 'WriteCostAllocation',
#        'WriteVersioningProps', 'EnableKeyRotation', 'Task', 'ListMetrics',
#        'ReadBucketAnalytics', 'ReadBucketReplication'], dtype=object)

# %%
az2op = pd.DataFrame(df[df['AvailabilityZone'].notna()][['AvailabilityZone', 'Operation']].groupby(['AvailabilityZone'])['Operation'].unique())

for each in az2op.iterrows():
    print(each[0])
    print(each[1].tolist())
    print()
    
# AZ可以做啥
# Out:
# ap-northeast-1
# [array(['CommittedThroughput', 'StandardStorage'], dtype=object)]
#
# ap-northeast-1a
# [array(['Hourly', 'RunInstances', 'T3CPUCredits', 'RunInstances:0002',
#        'RunInstances:0010'], dtype=object)]
#
# ap-northeast-1c
# [array(['RunInstances', 'T3CPUCredits', 'RunInstances:0010'], dtype=object)]
#
# ap-northeast-1d
# [array(['RunInstances', 'Hourly'], dtype=object)]
#
# ap-northeast-2a
# [array(['RunInstances'], dtype=object)]
#
# us-east-2
# [array(['CommittedThroughput'], dtype=object)]
#
# us-west-1
# [array(['CreateDBInstance', 'Not Applicable', 'CreateDBInstance:0014'],
#       dtype=object)]
#
# us-west-1a
# [array(['RunInstances'], dtype=object)]
#
# us-west-1c
# [array(['RunInstances'], dtype=object)]

# %% [markdown]
# ### By User
# 1. Find alert threshold (rule-based)
# 2. model
# ### By ProductName
# ### By Service

# %%
df['aws_createdBy'].unique()
# Out:
# array([nan, 'IAMUser:AIDAUJP5OVXBDUJ2EOQJH:Jaden.Mao',
#        'IAMUser:AIDAUJP5OVXBKSMQY5DKG:neilguan',
#        'IAMUser:AIDAUJP5OVXBPSQBM33Z2:ct-admin',
#        'AssumedRole:AROAUJP5OVXBEV2S7G5FX:AutoScaling',
#        'IAMUser:AIDAUJP5OVXBNWGZF4CL5:benkatsai',
#        'IAMUser:AIDAUJP5OVXBF6LJ3Z6LL:Sam',
#        'AssumedRole:AROAUJP5OVXBK7VONHMLJ:1604267547898754961',
#        'AssumedRole:AROAUJP5OVXBJZCW7TRAG:AWSCloudFormation',
#        'IAMUser:AIDAUJP5OVXBJXEFEVXCD:jameshsu',
#        'IAMUser:AIDAUJP5OVXBGEHPWHNJ5:LeonLin',
#        'IAMUser:AIDAUJP5OVXBFHQXHHQAL:CloudWen',
#        'IAMUser:AIDAUJP5OVXBJUIVZMVBC:marcuskuo',
#        'AssumedRole:AROAUJP5OVXBEGU6HTBBE:i-040c6bcb735a906fb',
#        'AssumedRole:AROAUJP5OVXBIIVB5F65L:AWSCloud9Workspace-295273672130',
#        'AssumedRole:AROAUJP5OVXBK7VONHMLJ:1611357218428526888',
#        'AssumedRole:AROAUJP5OVXBFJJ2HV7HZ:3479c807-942e-40e8-816b-6b421e772c90'],
#       dtype=object)

# %%
createby_df = df.dropna(subset=['aws_createdBy'])
iam_df = createby_df[createby_df['aws_createdBy'].str.contains('IAMUser')].copy()
iam_df['aws_createdBy'] = iam_df['aws_createdBy'].apply(lambda x: x[30:])

# iam_df
iam_df['aws_createdBy'].unique()
#使用頻率高、使用服務user
# Out:
# array(['Jaden.Mao', 'neilguan', 'ct-admin', 'benkatsai', 'Sam',
#        'jameshsu', 'LeonLin', 'CloudWen', 'marcuskuo'], dtype=object)

# %%
fe = iam_df.groupby('')
iam_df
# Out:
#                                          ProductName  \
# 1       OpenVPN Access Server (50 Connected Devices)
# 2       OpenVPN Access Server (50 Connected Devices)
# 3       OpenVPN Access Server (50 Connected Devices)
# 4       OpenVPN Access Server (50 Connected Devices)
# 5       OpenVPN Access Server (50 Connected Devices)
# ...                                              ...
# 135467                 Amazon Simple Storage Service
# 135486                  Amazon Elastic Compute Cloud
# 135495                 Amazon Simple Storage Service
# 135496                 Amazon Simple Storage Service
# 135507                 Amazon Simple Storage Service
#
#                            UsageType     Operation AvailabilityZone  \
# 1       APN1-SoftwareUsage:t3.medium        Hourly  ap-northeast-1a
# 2       APN1-SoftwareUsage:t3.medium        Hourly  ap-northeast-1a
# 3       APN1-SoftwareUsage:t3.medium        Hourly  ap-northeast-1a
# 4       APN1-SoftwareUsage:t3.medium        Hourly  ap-northeast-1a
# 5       APN1-SoftwareUsage:t3.medium        Hourly  ap-northeast-1a
# ...                              ...           ...              ...
# 135467       APS1-APN2-AWS-Out-Bytes       ReadACL              NaN
# 135486   APN1-DataTransfer-Out-Bytes  RunInstances              NaN
# 135495           APN1-Requests-Tier2    HeadBucket              NaN
# 135496           APN1-Requests-Tier2       ReadACL              NaN
# 135507                Requests-Tier2    HeadBucket              NaN
#
#               UsageStartDate          UsageEndDate  UsageQuantity  \
# 1       2021-02-01T00:00:00Z  2021-02-01T01:00:00Z   1.000000e+00
# 2       2021-02-01T01:00:00Z  2021-02-01T02:00:00Z   1.000000e+00
# 3       2021-02-01T02:00:00Z  2021-02-01T03:00:00Z   1.000000e+00
# 4       2021-02-01T03:00:00Z  2021-02-01T04:00:00Z   1.000000e+00
# 5       2021-02-01T04:00:00Z  2021-02-01T05:00:00Z   1.000000e+00
# ...                      ...                   ...            ...
# 135467  2021-02-28T22:00:00Z  2021-02-28T23:00:00Z   5.011000e-07
# 135486  2021-02-28T23:00:00Z  2021-03-01T00:00:00Z   5.374380e-05
# 135495  2021-02-28T23:00:00Z  2021-03-01T00:00:00Z   2.000000e+00
# 135496  2021-02-28T23:00:00Z  2021-03-01T00:00:00Z   1.000000e+00
# 135507  2021-02-28T23:00:00Z  2021-03-01T00:00:00Z   1.000000e+00
#
#         UnblendedRate  UnBlendedCost  \
# 1        3.000000e-01   3.000000e-01
# 2        3.000000e-01   3.000000e-01
# 3        3.000000e-01   3.000000e-01
# 4        3.000000e-01   3.000000e-01
# 5        3.000000e-01   3.000000e-01
# ...               ...            ...
# 135467   9.000000e-02   4.510000e-08
# 135486   1.140000e-01   6.126800e-06
# 135495   3.700000e-07   7.400000e-07
# 135496   3.700000e-07   3.700000e-07
# 135507   4.000000e-07   4.000000e-07
#
#                                                ResourceId aws_createdBy
# 1       arn:aws:ec2:ap-northeast-1:295273672130:instan...     Jaden.Mao
# 2       arn:aws:ec2:ap-northeast-1:295273672130:instan...     Jaden.Mao
# 3       arn:aws:ec2:ap-northeast-1:295273672130:instan...     Jaden.Mao
# 4       arn:aws:ec2:ap-northeast-1:295273672130:instan...     Jaden.Mao
# 5       arn:aws:ec2:ap-northeast-1:295273672130:instan...     Jaden.Mao
# ...                                                   ...           ...
# 135467  aws-cloudtrail-logs-295273672130-management-ev...     Jaden.Mao
# 135486                                i-08078581a91e15db5     benkatsai
# 135495                         config-bucket-295273672130     Jaden.Mao
# 135496                         config-bucket-295273672130     Jaden.Mao
# 135507                         config-bucket-295273672130     Jaden.Mao
#
# [27474 rows x 11 columns]

# %%
iam_df[iam_df['aws_createdBy'] =='Jaden.Mao'].groupby(by='ProductName').agg(np.std, ddof=0)
# Out:
#                                               UsageType  Operation  \
# ProductName
# Amazon Elastic Compute Cloud                        NaN        NaN
# Amazon Simple Storage Service                       NaN        NaN
# OpenVPN Access Server (50 Connected Devices)        NaN        NaN
#
#                                               AvailabilityZone  \
# ProductName
# Amazon Elastic Compute Cloud                               NaN
# Amazon Simple Storage Service                              NaN
# OpenVPN Access Server (50 Connected Devices)               NaN
#
#                                               UsageStartDate  UsageEndDate  \
# ProductName
# Amazon Elastic Compute Cloud                             NaN           NaN
# Amazon Simple Storage Service                            NaN           NaN
# OpenVPN Access Server (50 Connected Devices)             NaN           NaN
#
#                                               UsageQuantity  UnblendedRate  \
# ProductName
# Amazon Elastic Compute Cloud                       0.446172   4.767083e-02
# Amazon Simple Storage Service                     14.711801   3.954981e-02
# OpenVPN Access Server (50 Connected Devices)       0.000000   5.551115e-17
#
#                                               UnBlendedCost  ResourceId  \
# ProductName
# Amazon Elastic Compute Cloud                   2.530219e-02         NaN
# Amazon Simple Storage Service                  7.802895e-05         NaN
# OpenVPN Access Server (50 Connected Devices)   5.551115e-17         NaN
#
#                                               aws_createdBy
# ProductName
# Amazon Elastic Compute Cloud                            NaN
# Amazon Simple Storage Service                           NaN
# OpenVPN Access Server (50 Connected Devices)            NaN

# %%
iam_df[iam_df['aws_createdBy'] =='Jaden.Mao'].groupby(by='ProductName').mean()
# Out:
#                                               UsageQuantity  UnblendedRate  \
# ProductName
# Amazon Elastic Compute Cloud                       0.255570       0.047404
# Amazon Simple Storage Service                      5.285276       0.025759
# OpenVPN Access Server (50 Connected Devices)       1.000000       0.300000
#
#                                               UnBlendedCost
# ProductName
# Amazon Elastic Compute Cloud                       0.013550
# Amazon Simple Storage Service                      0.000024
# OpenVPN Access Server (50 Connected Devices)       0.300000

# %%
assume_df = createby_df[createby_df['aws_createdBy'].str.contains('AssumedRole')].copy()
assume_df['aws_createdBy'] = assume_df['aws_createdBy'].apply(lambda x: x[34:])

# assume_df pass
assume_df['aws_createdBy'].unique()
# Out:
# array(['AutoScaling', '1604267547898754961', 'AWSCloudFormation',
#        'i-040c6bcb735a906fb', 'AWSCloud9Workspace-295273672130',
#        '1611357218428526888', '3479c807-942e-40e8-816b-6b421e772c90'],
#       dtype=object)

# %%
df['ProductName'].unique()
# Out:
# array(['OpenVPN Access Server (50 Connected Devices)',
#        'Amazon Elastic Compute Cloud', 'AmazonCloudWatch',
#        'Elastic Load Balancing', 'Amazon Simple Storage Service',
#        'AWS Data Transfer', 'AWS Global Accelerator',
#        'AWS Secrets Manager', 'Amazon Relational Database Service',
#        'AWS Key Management Service', 'Amazon Elastic Container Service',
#        'Amazon Elastic Container Service for Kubernetes', 'AWS Amplify',
#        'Amazon DynamoDB', 'Amazon Elastic Container Registry Public',
#        'Amazon Kinesis', 'Amazon EC2 Container Registry (ECR)',
#        'Amazon Elastic File System', 'AWS CloudTrail', 'Amazon Route 53',
#        'AWS Lambda', 'Amazon Simple Notification Service',
#        'Amazon Simple Queue Service', 'AWS Config', 'AWS Step Functions',
#        'AWS CodeArtifact', 'Amazon CloudFront'], dtype=object)

# %%
compute_list = ['Amazon Elastic Compute Cloud', 'AWS Lambda',]
network_list = ['Elastic Load Balancing','AWS Global Accelerator','Amazon Route 53','Amazon CloudFront']
storage_list = ['Amazon Simple Storage Service', 'Amazon Elastic File System',]
montr_list = ['AWS CloudTrail', 'AWS Config', ]
app_list = ['Amazon Simple Notification Service', 'Amazon Simple Queue Service', 'AWS Step Functions',]
dev_list = [ 'AWS CodeArtifact',]
sec_list = ['AWS Secrets Manager','AWS Key Management Service',]
db_list = ['Amazon Relational Database Service', 'Amazon DynamoDB',]
ctr_list = ['Amazon Elastic Container Service','Amazon Elastic Container Service for Kubernetes','Amazon Elastic Container Registry Public', 'Amazon EC2 Container Registry (ECR)',]
fe_list = ['AWS Amplify',]
media_list = ['Amazon Kinesis',]

# %%
df[df['ProductName'].isin(compute_list)]['Operation'].unique()
# Out:
# array(['RunInstances', 'RunInstances:0010', 'T3CPUCredits',
#        'RunInstances:0010:SV008', 'PublicIP-Out', 'InterZone-In',
#        'InterZone-Out', 'CreateVolume-Gp2', 'Hourly',
#        'AssociateAddressVPC', 'NatGateway', 'AWSGlobalAccelerator',
#        'RunInstances:0002', 'PublicIP-In', 'Invoke', 'RunInstances:SV012',
#        'RunInstances:SV008', 'CreateSnapshot', 'RunInstances:0010:SV012',
#        nan], dtype=object)
